# %%
import pandas as pd

# %%
path = ("../Resources/Weather_Data.csv")
df = pd.read_csv(path)
df
# Out:
#            STATION                                        NAME   LATITUDE  \
# 0      US1ILDP0098                  DOWNERS GROVE 0.9 S, IL US  41.784019
# 1      US1ILDP0098                  DOWNERS GROVE 0.9 S, IL US  41.784019
# 2      US1ILDP0098                  DOWNERS GROVE 0.9 S, IL US  41.784019
# 3      US1ILDP0098                  DOWNERS GROVE 0.9 S, IL US  41.784019
# 4      US1ILDP0098                  DOWNERS GROVE 0.9 S, IL US  41.784019
# ...            ...                                         ...        ...
# 23501  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  41.960190
# 23502  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  41.960190
# 23503  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  41.960190
# 23504  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  41.960190
# 23505  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  41.960190
#
#        LONGITUDE  ELEVATION        DATE   AWND AWND_ATTRIBUTES  DAPR  \
# ...
