# %%
import pandas as pd

# %%
path= "Resources/Beach_Lab_Data.csv"
df = pd.read_csv(path)
df
# Out:
#        DNA Test ID    DNA Sample Timestamp              Beach  \
# 0              NaN                     NaN                NaN
# 1              NaN                     NaN                NaN
# 2              NaN                     NaN                NaN
# 3          10601.0  06/03/2019 12:08:00 PM        63rd Street
# 4          10600.0  06/03/2019 12:08:00 PM        South Shore
# ...            ...                     ...                ...
# 25275      15383.0  07/24/2021 11:13:00 AM            Calumet
# 25276      15419.0  07/24/2021 11:16:00 AM              Leone
# 25277      15418.0  07/24/2021 11:16:00 AM  Hartigan (Albion)
# 25278      15392.0  07/24/2021 11:15:00 AM         Oak Street
# 25279      15413.0  07/24/2021 11:15:00 AM           Humboldt
#
#        DNA Sample 1 Reading  DNA Sample 2 Reading  DNA Reading Mean  \
# 0                       NaN                   NaN               NaN
# 1                       NaN                   NaN               NaN
# ...

# %%
big = df.groupby(['Beach']).size()
big.sort_values(ascending=False)
# Out:
# Beach
# Calumet                           1276
# Montrose                          1249
# 63rd Street                       1233
# Rainbow                           1229
# South Shore                       1216
# Ohio Street                       1215
# 12th Street                       1210
# 57th Street                       1189
# North Avenue                      1189
# Osterman                          1182
# Foster                            1177
# Oak Street                        1162
# Howard                            1094
# Rogers                            1077
# Leone                              954
# Oakwood                            950
# Margaret T Burroughs               833
# Hartigan                           794
# Juneway                            789
# Marion Mahony Griffin              728
# Montrose Dog                       440
# Margaret T Burroughs (31st)        430
# Hartigan (Albion)                  364
# Marion Mahony Griffin (Jarvis)     361
# ...

# %%
df.dtypes
# Out:
# DNA Test ID                   float64
# DNA Sample Timestamp           object
# Beach                          object
# DNA Sample 1 Reading          float64
# DNA Sample 2 Reading          float64
# DNA Reading Mean              float64
# Culture Test ID               float64
# Culture Sample 1 Timestamp     object
# Culture Sample 1 Reading      float64
# Culture Sample 2 Reading      float64
# Culture Reading Mean          float64
# Culture Note                  float64
# Culture Sample Interval       float64
# Culture Sample 2 Timestamp     object
# Latitude                      float64
# Longitude                     float64
# Location                       object
# dtype: object

# %%
df['DNA Sample Timestamp']= pd.to_datetime(df['DNA Sample Timestamp'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2084         try:
# -> 2085             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    2086             # If tzaware, these values represent unix timestamps, so we
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# <ipython-input-29-7ec078e4eb2a> in <module>
# ----> 1 df['DNA Sample Timestamp']= pd.to_datetime(df['DNA Sample Timestamp'])
#
# ...
